# %%
# !pip install holoviews
# Out:
# Collecting holoviews
#   Using cached holoviews-1.18.3-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: param<3.0,>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from holoviews) (2.1.0)
# Requirement already satisfied: numpy>=1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from holoviews) (1.26.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from holoviews) (3.0.2)
# Requirement already satisfied: panel>=1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from holoviews) (1.4.1)
# Requirement already satisfied: colorcet in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from holoviews) (3.1.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from holoviews) (23.2)
# Requirement already satisfied: pandas>=0.20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from holoviews) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.20.0->holoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.20.0->holoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.20.0->holoviews) (2023.3)
# Requirement already satisfied: bokeh<3.5.0,>=3.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (3.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (2024.4.0)
# Requirement already satisfied: markdown in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (3.6)
# Requirement already satisfied: markdown-it-py in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (3.0.0)
# Requirement already satisfied: linkify-it-py in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (0.4.0)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (4.66.2)
# Requirement already satisfied: bleach in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (6.1.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from panel>=1.0->holoviews) (4.11.0)
# Requirement already satisfied: Jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->panel>=1.0->holoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->panel>=1.0->holoviews) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->panel>=1.0->holoviews) (10.1.0)
# Requirement already satisfied: PyYAML>=3.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->panel>=1.0->holoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->panel>=1.0->holoviews) (6.3.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->holoviews) (1.16.0)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from bleach->panel>=1.0->holoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from linkify-it-py->panel>=1.0->holoviews) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from markdown-it-py->panel>=1.0->holoviews) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->panel>=1.0->holoviews) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->panel>=1.0->holoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->panel>=1.0->holoviews) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->panel>=1.0->holoviews) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from Jinja2>=2.9->bokeh<3.5.0,>=3.4.0->panel>=1.0->holoviews) (2.1.3)
# Using cached holoviews-1.18.3-py2.py3-none-any.whl (4.3 MB)
# Installing collected packages: holoviews
# Successfully installed holoviews-1.18.3

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (23.3.2)
# Collecting pip
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.2
#     Uninstalling pip-23.3.2:
#       Successfully uninstalled pip-23.3.2
# Successfully installed pip-24.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import holoviews as hv

# %%
#Import the data. The dataset is provided in the GitHub repository.
hv.extension('bokeh')
table_ = pd.read_csv('sankey_table')
table_.head(20)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1006'>
#   <div id="f6ec7751-ae07-4a76-aa11-b5777eb59ae4" data-root-id="p1006" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"be363d16-7af6-4b24-a45f-5b2f5d96f7f2":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1006"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1007","attributes":{"plot_id":"p1006","comm_id":"3834e9b072ac400489fd6a6825307bf0","client_comm_id":"71eaa25169cb49d09217fed0563ae799"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"be363d16-7af6-4b24-a45f-5b2f5d96f7f2","roots":{"p1006":"f6ec7751-ae07-4a76-aa11-b5777eb59ae4"},"root_ids":["p1006"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
#     user_id  cycle_number              status
# 0         1             1  Potential Customer
# 1         1             2  Potential Customer
# 2         1             3  Potential Customer
# 3         1             4  Potential Customer
# 4         1             5               Churn
# 5      7368             1            No Churn
# 6      7368             2            No Churn
# 7      7368             3               Churn
# 8     22159             1            No Churn
# 9     22159             2  Potential Customer
# 10    22159             3               Churn
# 11    22386             1            No Churn
# 12    22386             2               Churn
# 13    26498             1            No Churn
# 14    26498             2            No Churn
# 15    26498             3               Churn
# 16    28250             1            No Churn
# 17    28250             2            No Churn
# 18    28250             3               Churn
# 19    30678             1  Potential Customer

# %%
#Exploratory Data Analysis
table_['cycle_number'].value_counts()
# Out:
# cycle_number
# 1     20098
# 2     14681
# 3      9782
# 4      6313
# 5      3721
# 6      2055
# 7      1014
# 8       386
# 9        71
# 10        7
# Name: count, dtype: int64

# %%
table_['status'].value_counts()
# Out:
# status
# No Churn              28002
# Churn                 20098
# Potential Customer    10028
# Name: count, dtype: int64

# %%
# We will self join the table on user_id
# The reason we are doing is that we want to know how many people transistion from each cycle and status to the next cycle and status. 
# Once we have this table we can groupby and count the number of people in each of these unique pairs. That way we will get number
# of poeple transistioning from source to target column. Remember the final output table that we aim to achieve is having 3 columns - 
# Source, Target and value( or count)
new_table = table_.merge(table_, on = 'user_id')
new_table
# Out:
#         user_id  cycle_number_x            status_x  cycle_number_y  \
# 0             1               1  Potential Customer               1
# 1             1               1  Potential Customer               2
# 2             1               1  Potential Customer               3
# 3             1               1  Potential Customer               4
# 4             1               1  Potential Customer               5
# ...         ...             ...                 ...             ...
# 233643   107461               1               Churn               1
# 233644   107473               1               Churn               1
# 233645   107476               1               Churn               1
# 233646   107481               1               Churn               1
# 233647   107487               1               Churn               1
#
#                   status_y
# 0       Potential Customer
# 1       Potential Customer
# 2       Potential Customer
# 3       Potential Customer
# 4                    Churn
# ...                    ...
# 233643               Churn
# 233644               Churn
# 233645               Churn
# 233646               Churn
# 233647               Churn
#
# [233648 rows x 5 columns]

# %%
# Let us only consider those transition from one cycle to the immediate next. And assume there are no jumps with multiple steps.
# for example we dont have any people going from cycle 2 to cycle 5. 
new_table = new_table[new_table['cycle_number_y'] - new_table['cycle_number_x'] == 1]
new_table
# Out:
#         user_id  cycle_number_x            status_x  cycle_number_y  \
# 1             1               1  Potential Customer               2
# 7             1               2  Potential Customer               3
# 13            1               3  Potential Customer               4
# 19            1               4  Potential Customer               5
# 26         7368               1            No Churn               2
# ...         ...             ...                 ...             ...
# 233345   106863               1  Potential Customer               2
# 233362   106884               1  Potential Customer               2
# 233398   106934               1  Potential Customer               2
# 233405   106940               1  Potential Customer               2
# 233551   107190               1  Potential Customer               2
#
#                   status_y
# 1       Potential Customer
# 7       Potential Customer
# 13      Potential Customer
# 19                   Churn
# 26                No Churn
# ...                    ...
# 233345               Churn
# 233362               Churn
# 233398               Churn
# 233405               Churn
# 233551               Churn
#
# [38030 rows x 5 columns]

# %%
# We are taking groupby to get count of people in each unique cycle/status transition.
tab_group = new_table.groupby(['cycle_number_x', 'status_x', 'cycle_number_y', 'status_y']).count()
tab_group.reset_index(inplace = True)

# %%
tab_group.head(25)
# Out:
#     cycle_number_x            status_x  cycle_number_y            status_y  \
# 0                1            No Churn               2               Churn
# 1                1            No Churn               2            No Churn
# 2                1            No Churn               2  Potential Customer
# 3                1  Potential Customer               2               Churn
# 4                1  Potential Customer               2            No Churn
# 5                1  Potential Customer               2  Potential Customer
# 6                2            No Churn               3               Churn
# 7                2            No Churn               3            No Churn
# 8                2            No Churn               3  Potential Customer
# 9                2  Potential Customer               3               Churn
# 10               2  Potential Customer               3            No Churn
# 11               2  Potential Customer               3  Potential Customer
# 12               3            No Churn               4               Churn
# 13               3            No Churn               4            No Churn
# 14               3            No Churn               4  Potential Customer
# 15               3  Potential Customer               4               Churn
# 16               3  Potential Customer               4            No Churn
# 17               3  Potential Customer               4  Potential Customer
# 18               4            No Churn               5               Churn
# 19               4            No Churn               5            No Churn
# 20               4            No Churn               5  Potential Customer
# 21               4  Potential Customer               5               Churn
# 22               4  Potential Customer               5            No Churn
# 23               4  Potential Customer               5  Potential Customer
# 24               5            No Churn               6               Churn
#
#     user_id
# 0      3729
# 1      6274
# 2      1458
# 3      1170
# 4      1575
# 5       475
# 6      2699
# 7      3989
# 8      1161
# 9       770
# 10      401
# 11      762
# 12     1722
# 13     2009
# 14      659
# 15      870
# 16      309
# 17      744
# 18     1024
# 19      975
# 20      319
# 21      642
# 22      203
# 23      558
# 24      567

# %%
# Let us create another column which is unique to each cycle and status pair just by concatenating.
tab_group['source'] = tab_group.apply(lambda x: str(x['cycle_number_x'])+ ' - ' + str(x['status_x']), axis = 1)
tab_group['target'] = tab_group.apply(lambda x: str(x['cycle_number_y'])+ ' - ' + str(x['status_y']), axis = 1)
# We want the column names to be exactly in the order - source, target and value. And even the string should be exactly the same.

# %%
tab_group
# Out:
#     cycle_number_x            status_x  cycle_number_y            status_y  \
# 0                1            No Churn               2               Churn
# 1                1            No Churn               2            No Churn
# 2                1            No Churn               2  Potential Customer
# 3                1  Potential Customer               2               Churn
# 4                1  Potential Customer               2            No Churn
# 5                1  Potential Customer               2  Potential Customer
# 6                2            No Churn               3               Churn
# 7                2            No Churn               3            No Churn
# 8                2            No Churn               3  Potential Customer
# 9                2  Potential Customer               3               Churn
# 10               2  Potential Customer               3            No Churn
# 11               2  Potential Customer               3  Potential Customer
# 12               3            No Churn               4               Churn
# 13               3            No Churn               4            No Churn
# 14               3            No Churn               4  Potential Customer
# 15               3  Potential Customer               4               Churn
# 16               3  Potential Customer               4            No Churn
# 17               3  Potential Customer               4  Potential Customer
# 18               4            No Churn               5               Churn
# 19               4            No Churn               5            No Churn
# 20               4            No Churn               5  Potential Customer
# 21               4  Potential Customer               5               Churn
# 22               4  Potential Customer               5            No Churn
# 23               4  Potential Customer               5  Potential Customer
# 24               5            No Churn               6               Churn
# 25               5            No Churn               6            No Churn
# 26               5            No Churn               6  Potential Customer
# 27               5  Potential Customer               6               Churn
# 28               5  Potential Customer               6            No Churn
# 29               5  Potential Customer               6  Potential Customer
# 30               6            No Churn               7               Churn
# 31               6            No Churn               7            No Churn
# 32               6            No Churn               7  Potential Customer
# 33               6  Potential Customer               7               Churn
# 34               6  Potential Customer               7            No Churn
# 35               6  Potential Customer               7  Potential Customer
# 36               7            No Churn               8               Churn
# 37               7            No Churn               8            No Churn
# 38               7            No Churn               8  Potential Customer
# 39               7  Potential Customer               8               Churn
# 40               7  Potential Customer               8            No Churn
# 41               7  Potential Customer               8  Potential Customer
# 42               8            No Churn               9               Churn
# 43               8            No Churn               9            No Churn
# 44               8            No Churn               9  Potential Customer
# 45               8  Potential Customer               9               Churn
# 46               8  Potential Customer               9            No Churn
# 47               8  Potential Customer               9  Potential Customer
# 48               9            No Churn              10               Churn
# 49               9  Potential Customer              10               Churn
#
#     user_id                  source                  target
# 0      3729            1 - No Churn               2 - Churn
# 1      6274            1 - No Churn            2 - No Churn
# 2      1458            1 - No Churn  2 - Potential Customer
# 3      1170  1 - Potential Customer               2 - Churn
# 4      1575  1 - Potential Customer            2 - No Churn
# 5       475  1 - Potential Customer  2 - Potential Customer
# 6      2699            2 - No Churn               3 - Churn
# 7      3989            2 - No Churn            3 - No Churn
# 8      1161            2 - No Churn  3 - Potential Customer
# 9       770  2 - Potential Customer               3 - Churn
# 10      401  2 - Potential Customer            3 - No Churn
# 11      762  2 - Potential Customer  3 - Potential Customer
# 12     1722            3 - No Churn               4 - Churn
# 13     2009            3 - No Churn            4 - No Churn
# 14      659            3 - No Churn  4 - Potential Customer
# 15      870  3 - Potential Customer               4 - Churn
# 16      309  3 - Potential Customer            4 - No Churn
# 17      744  3 - Potential Customer  4 - Potential Customer
# 18     1024            4 - No Churn               5 - Churn
# 19      975            4 - No Churn            5 - No Churn
# 20      319            4 - No Churn  5 - Potential Customer
# 21      642  4 - Potential Customer               5 - Churn
# 22      203  4 - Potential Customer            5 - No Churn
# 23      558  4 - Potential Customer  5 - Potential Customer
# 24      567            5 - No Churn               6 - Churn
# 25      445            5 - No Churn            6 - No Churn
# 26      166            5 - No Churn  6 - Potential Customer
# 27      474  5 - Potential Customer               6 - Churn
# 28       96  5 - Potential Customer            6 - No Churn
# 29      307  5 - Potential Customer  6 - Potential Customer
# 30      333            6 - No Churn               7 - Churn
# 31      164            6 - No Churn            7 - No Churn
# 32       44            6 - No Churn  7 - Potential Customer
# 33      295  6 - Potential Customer               7 - Churn
# 34       53  6 - Potential Customer            7 - No Churn
# 35      125  6 - Potential Customer  7 - Potential Customer
# 36      173            7 - No Churn               8 - Churn
# 37       39            7 - No Churn            8 - No Churn
# 38        5            7 - No Churn  8 - Potential Customer
# 39      142  7 - Potential Customer               8 - Churn
# 40        6  7 - Potential Customer            8 - No Churn
# 41       21  7 - Potential Customer  8 - Potential Customer
# 42       41            8 - No Churn               9 - Churn
# 43        2            8 - No Churn            9 - No Churn
# 44        2            8 - No Churn  9 - Potential Customer
# 45       23  8 - Potential Customer               9 - Churn
# 46        1  8 - Potential Customer            9 - No Churn
# 47        2  8 - Potential Customer  9 - Potential Customer
# 48        3            9 - No Churn              10 - Churn
# 49        4  9 - Potential Customer              10 - Churn

# %%
# we want the count to be named as value. 
tab_group.rename(columns = {'user_id': 'value'}, inplace = True)

# %%
edges = tab_group[['source', 'target', 'value']]
edges
# THis is the final table
# Out:
#                     source                  target  value
# 0             1 - No Churn               2 - Churn   3729
# 1             1 - No Churn            2 - No Churn   6274
# 2             1 - No Churn  2 - Potential Customer   1458
# 3   1 - Potential Customer               2 - Churn   1170
# 4   1 - Potential Customer            2 - No Churn   1575
# 5   1 - Potential Customer  2 - Potential Customer    475
# 6             2 - No Churn               3 - Churn   2699
# 7             2 - No Churn            3 - No Churn   3989
# 8             2 - No Churn  3 - Potential Customer   1161
# 9   2 - Potential Customer               3 - Churn    770
# 10  2 - Potential Customer            3 - No Churn    401
# 11  2 - Potential Customer  3 - Potential Customer    762
# 12            3 - No Churn               4 - Churn   1722
# 13            3 - No Churn            4 - No Churn   2009
# 14            3 - No Churn  4 - Potential Customer    659
# 15  3 - Potential Customer               4 - Churn    870
# 16  3 - Potential Customer            4 - No Churn    309
# 17  3 - Potential Customer  4 - Potential Customer    744
# 18            4 - No Churn               5 - Churn   1024
# 19            4 - No Churn            5 - No Churn    975
# 20            4 - No Churn  5 - Potential Customer    319
# 21  4 - Potential Customer               5 - Churn    642
# 22  4 - Potential Customer            5 - No Churn    203
# 23  4 - Potential Customer  5 - Potential Customer    558
# 24            5 - No Churn               6 - Churn    567
# 25            5 - No Churn            6 - No Churn    445
# 26            5 - No Churn  6 - Potential Customer    166
# 27  5 - Potential Customer               6 - Churn    474
# 28  5 - Potential Customer            6 - No Churn     96
# 29  5 - Potential Customer  6 - Potential Customer    307
# 30            6 - No Churn               7 - Churn    333
# 31            6 - No Churn            7 - No Churn    164
# 32            6 - No Churn  7 - Potential Customer     44
# 33  6 - Potential Customer               7 - Churn    295
# 34  6 - Potential Customer            7 - No Churn     53
# 35  6 - Potential Customer  7 - Potential Customer    125
# 36            7 - No Churn               8 - Churn    173
# 37            7 - No Churn            8 - No Churn     39
# 38            7 - No Churn  8 - Potential Customer      5
# 39  7 - Potential Customer               8 - Churn    142
# 40  7 - Potential Customer            8 - No Churn      6
# 41  7 - Potential Customer  8 - Potential Customer     21
# 42            8 - No Churn               9 - Churn     41
# 43            8 - No Churn            9 - No Churn      2
# 44            8 - No Churn  9 - Potential Customer      2
# 45  8 - Potential Customer               9 - Churn     23
# 46  8 - Potential Customer            9 - No Churn      1
# 47  8 - Potential Customer  9 - Potential Customer      2
# 48            9 - No Churn              10 - Churn      3
# 49  9 - Potential Customer              10 - Churn      4

# %%
hv.extension('bokeh')
sankey = hv.Sankey(edges, label='A Breakout of cycle stages')
sankey.opts(label_position='left', edge_color='target', node_color='index', cmap='tab20')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1008'>
#   <div id="ac368c7c-ad80-4511-b299-3926d8bcc6c7" data-root-id="p1008" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"bd0da30f-119f-4ec9-bf59-c839c0ef1dc1":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1008"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1009","attributes":{"plot_id":"p1008","comm_id":"34d3f7307425421392dbde815a204426","client_comm_id":"3719fe3f69254820b6af0ab5002ae914"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"bd0da30f-119f-4ec9-bf59-c839c0ef1dc1","roots":{"p1008":"ac368c7c-ad80-4511-b299-3926d8bcc6c7"},"root_ids":["p1008"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Sankey   [source,target]   (value)

# %%
# Looks like the graph is over cluttered. Let us remove stages beyond 6
hv.extension('bokeh')
sankey = hv.Sankey(edges.head(30), label='A Breakout of cycle stages')
sankey.opts(label_position='left', edge_color='target', node_color='index', cmap='tab20')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1240'>
#   <div id="d83a56c5-3bf2-4f75-837c-8d7b650f04d1" data-root-id="p1240" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"94570908-13e2-4cb7-8f78-5b21200477d9":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1240"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1241","attributes":{"plot_id":"p1240","comm_id":"881633ff039247cd8204ad6045b098f4","client_comm_id":"bb2ea2abe9564acfa070d735082aa647"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"94570908-13e2-4cb7-8f78-5b21200477d9","roots":{"p1240":"d83a56c5-3bf2-4f75-837c-8d7b650f04d1"},"root_ids":["p1240"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Sankey   [source,target]   (value)

# %% [markdown]
# ## Now this looks beautiful isn’t it!!
